# %%
import time
import requests
import pandas as pd
from io import StringIO
from pathlib import Path

BASE_URL = "https://apihub.kma.go.kr/api/typ01/cgi-bin/url/nph-aws2_min"

AUTH_KEY = "bWb9TUUATEGm_U1FAExBlg"
STN = "368"

OUT_CSV = Path("AWS_368.csv")
N_CALLS = 1000 # 총 1000번

WINDOW_HOURS = 20 # 12시간

STEP_MINUTES = 1 # 마지막 관측시각 + 1분

TIMEOUT_SEC = 60 # 60초 동안 기다림
SLEEP_SEC = 0.5 # 너무 빠르면 막힐 수 있어 약간 쉬기(필요 시 조절)

COLS = [
    "YYMMDDHHMI", "STN",
    "WD1", "WS1", "WDS", "WSS",
    "WD10", "WS10",
    "TA", "RE",
    "RN_15m", "RN_60m", "RN_12H", "RN_DAY",
    "HM", "PA", "PS", "TD"
]

# %%
def fetch_text(tm1: str, tm2: str) -> str:
    params = {
        "tm1": tm1,
        "tm2": tm2,
        "stn": STN,
        "disp": "1",
        "help": "0",
        "authKey": AUTH_KEY
    }
    r = requests.get(BASE_URL, params=params, timeout=TIMEOUT_SEC)
    r.raise_for_status()
    return r.text

# %%
def parse_kma_text_to_df(text: str) -> pd.DataFrame:
    # 1) 주석/빈줄 제거
    lines = []
    for ln in text.splitlines():
        ln = ln.strip()
        if not ln or ln.startswith("#"):
            continue
        lines.append(ln)

    if not lines:
        return pd.DataFrame(columns=COLS)

    # 2) 끝 토큰 '=' 제거
    cleaned = []
    for ln in lines:
        if ln.endswith(",="):
            ln = ln[:-2]
        elif ln.endswith("="):
            ln = ln[:-1]
            if ln.endswith(","):
                ln = ln[:-1]
        cleaned.append(ln)

    df = pd.read_csv(StringIO("\n".join(cleaned)), header=None, dtype=str)

    # 열수 체크
    if df.shape[1] != len(COLS):
        # 포맷이 바뀌었거나 에러 메시지가 섞인 경우가 흔함
        raise ValueError(f"컬럼 수 불일치: expected={len(COLS)}, got={df.shape[1]}")

    df.columns = COLS

    # datetime 파생
    df["datetime"] = pd.to_datetime(df["YYMMDDHHMI"], format="%Y%m%d%H%M", errors="coerce")

    # 숫자 변환
    for c in df.columns:
        if c in ("YYMMDDHHMI", "datetime"):
            continue
        df[c] = pd.to_numeric(df[c], errors="coerce")

    # 결측 센티넬(-99.x) 처리
    num_cols = [c for c in df.columns if c not in ("YYMMDDHHMI", "datetime")]
    for c in num_cols:
        df.loc[df[c] <= -99, c] = pd.NA

    return df

# %%
def dt_to_tm(dt: pd.Timestamp) -> str:
    # KST 타임존을 별도로 붙이지 않아도, 문자열 기준으로 굴리면 충분함(네 데이터가 KST임)
    return dt.strftime("%Y%m%d%H%M")

# %%
def append_df_to_csv(df: pd.DataFrame, path: Path):
    if df.empty:
        return
    write_header = not path.exists()
    df.to_csv(path, mode="a", index=False, encoding="utf-8-sig", header=write_header)

# %%
def infer_next_tm1_from_existing_csv(path: Path, fallback_tm1: str) -> str:
    if not path.exists():
        return fallback_tm1

    # 큰 파일이면 tail 방식이 좋지만, 여기선 간단하게 마지막 행만 읽음
    last = pd.read_csv(path, usecols=["YYMMDDHHMI"]).tail(1)
    if last.empty:
        return fallback_tm1

    last_dt = pd.to_datetime(last["YYMMDDHHMI"].iloc[0], format="%Y%m%d%H%M", errors="coerce")
    if pd.isna(last_dt):
        return fallback_tm1

    next_dt = last_dt + pd.Timedelta(minutes=STEP_MINUTES)
    return dt_to_tm(next_dt)

# %%
INITIAL_TM1 = "202408010000"  # 첫 실행용 기본값
tm1 = infer_next_tm1_from_existing_csv(OUT_CSV, INITIAL_TM1)

for i in range(N_CALLS):
    start_dt = pd.to_datetime(tm1, format="%Y%m%d%H%M")
    end_dt = start_dt + pd.Timedelta(hours=WINDOW_HOURS)
    tm2 = dt_to_tm(end_dt)

    print(f"[{i+1}/{N_CALLS}] tm1={tm1} tm2={tm2}")

    try:
        text = fetch_text(tm1, tm2)
        df = parse_kma_text_to_df(text)

        # 혹시 중복이 생기면(이어받기/겹침) 제거
        if not df.empty:
            df = df.drop_duplicates(subset=["YYMMDDHHMI", "STN"], keep="last")

        append_df_to_csv(df, OUT_CSV)

        # 다음 tm1 = 이번 응답의 마지막 datetime + 1분
        if df.empty or df["datetime"].isna().all():
            # 데이터가 비었으면 그냥 윈도우를 앞으로 한 칸 이동(12시간)
            tm1 = dt_to_tm(end_dt + pd.Timedelta(minutes=STEP_MINUTES))
        else:
            last_dt = df["datetime"].max()
            tm1 = dt_to_tm(last_dt + pd.Timedelta(minutes=STEP_MINUTES))

    except Exception as e:
        # 에러 나면 너무 멀리 점프하지 말고, 일단 12시간 뒤로만 이동해서 계속
        print("  [error]", repr(e))
        tm1 = dt_to_tm(end_dt + pd.Timedelta(minutes=STEP_MINUTES))

    time.sleep(SLEEP_SEC)

print("DONE:", OUT_CSV.resolve())
# Out:
# [1/1000] tm1=202408010000 tm2=202408012000
# [2/1000] tm1=202408011604 tm2=202408021204
# [3/1000] tm1=202408020808 tm2=202408030408
# [4/1000] tm1=202408030141 tm2=202408032141
# [5/1000] tm1=202408031803 tm2=202408041403
# [6/1000] tm1=202408041020 tm2=202408050620
# [7/1000] tm1=202408042220 tm2=202408051820
# [8/1000] tm1=202408051821 tm2=202408061421
# [9/1000] tm1=202408061224 tm2=202408070824
# [10/1000] tm1=202408070349 tm2=202408072349
#   [error] HTTPError('504 Server Error: Gateway Timeout for url: https://apihub.kma.go.kr/api/typ01/cgi-bin/url/nph-aws2_min?tm1=202408070349&tm2=202408072349&stn=368&disp=1&help=0&authKey=bWb9TUUATEGm_U1FAExBlg')
# [11/1000] tm1=202408072350 tm2=202408081950
# [12/1000] tm1=202408080414 tm2=202408090014
# [13/1000] tm1=202408081333 tm2=202408090933
# [14/1000] tm1=202408090134 tm2=202408092134
# [15/1000] tm1=202408091758 tm2=202408101358
# [16/1000] tm1=202408100648 tm2=202408110248
# [17/1000] tm1=202408102256 tm2=202408111856
# [18/1000] tm1=202408111655 tm2=202408121255
# [19/1000] tm1=202408120928 tm2=202408130528
# [20/1000] tm1=202408122244 tm2=202408131844
# [21/1000] tm1=202408131359 tm2=202408140959
# [22/1000] tm1=202408140546 tm2=202408150146
# [23/1000] tm1=202408142139 tm2=202408151739
# [24/1000] tm1=202408151342 tm2=202408160942
# [25/1000] tm1=202408160522 tm2=202408170122
# [26/1000] tm1=202408162039 tm2=202408171639
# [27/1000] tm1=202408171215 tm2=202408180815
# [28/1000] tm1=202408180002 tm2=202408182002
# [29/1000] tm1=202408181606 tm2=202408191206
# [30/1000] tm1=202408190745 tm2=202408200345
# [31/1000] tm1=202408192129 tm2=202408201729
# [32/1000] tm1=202408201218 tm2=202408210818
# [33/1000] tm1=202408202000 tm2=202408211600
# [34/1000] tm1=202408211122 tm2=202408220722
# [35/1000] tm1=202408220418 tm2=202408230018
# [36/1000] tm1=202408221105 tm2=202408230705
# [37/1000] tm1=202408230234 tm2=202408232234
# [38/1000] tm1=202408232002 tm2=202408241602
# [39/1000] tm1=202408240128 tm2=202408242128
# [40/1000] tm1=202408240434 tm2=202408250034
# [41/1000] tm1=202408241217 tm2=202408250817
# [42/1000] tm1=202408250339 tm2=202408252339
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [43/1000] tm1=202408252340 tm2=202408261940
# [44/1000] tm1=202408261400 tm2=202408271000
# [45/1000] tm1=202408270348 tm2=202408272348
# [46/1000] tm1=202408271011 tm2=202408280611
# [47/1000] tm1=202408280148 tm2=202408282148
# [48/1000] tm1=202408281524 tm2=202408291124
# [49/1000] tm1=202408290534 tm2=202408300134
# [50/1000] tm1=202408291648 tm2=202408301248
# [51/1000] tm1=202408300211 tm2=202408302211
# [52/1000] tm1=202408301619 tm2=202408311219
# [53/1000] tm1=202408310618 tm2=202409010218
# [54/1000] tm1=202408312032 tm2=202409011632
# [55/1000] tm1=202409011044 tm2=202409020644
# [56/1000] tm1=202409012206 tm2=202409021806
# [57/1000] tm1=202409021130 tm2=202409030730
# [58/1000] tm1=202409030204 tm2=202409032204
# [59/1000] tm1=202409031632 tm2=202409041232
# [60/1000] tm1=202409040339 tm2=202409042339
# [61/1000] tm1=202409041019 tm2=202409050619
# [62/1000] tm1=202409042346 tm2=202409051946
# [63/1000] tm1=202409051602 tm2=202409061202
# [64/1000] tm1=202409060229 tm2=202409062229
# [65/1000] tm1=202409061357 tm2=202409070957
# [66/1000] tm1=202409070240 tm2=202409072240
# [67/1000] tm1=202409071810 tm2=202409081410
# [68/1000] tm1=202409081040 tm2=202409090640
# [69/1000] tm1=202409082300 tm2=202409091900
# [70/1000] tm1=202409091037 tm2=202409100637
# [71/1000] tm1=202409100210 tm2=202409102210
# [72/1000] tm1=202409101933 tm2=202409111533
# [73/1000] tm1=202409111045 tm2=202409120645
# [74/1000] tm1=202409111216 tm2=202409120816
# [75/1000] tm1=202409120303 tm2=202409122303
# [76/1000] tm1=202409121927 tm2=202409131527
# [77/1000] tm1=202409130040 tm2=202409132040
# [78/1000] tm1=202409130823 tm2=202409140423
# [79/1000] tm1=202409132300 tm2=202409141900
# [80/1000] tm1=202409141344 tm2=202409150944
# [81/1000] tm1=202409150504 tm2=202409160104
# [82/1000] tm1=202409151401 tm2=202409161001
# [83/1000] tm1=202409160520 tm2=202409170120
# [84/1000] tm1=202409162023 tm2=202409171623
# [85/1000] tm1=202409171227 tm2=202409180827
# [86/1000] tm1=202409180334 tm2=202409182334
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [87/1000] tm1=202409182335 tm2=202409191935
# [88/1000] tm1=202409191459 tm2=202409201059
# [89/1000] tm1=202409200600 tm2=202409210200
# [90/1000] tm1=202409201939 tm2=202409211539
# [91/1000] tm1=202409211248 tm2=202409220848
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [92/1000] tm1=202409220849 tm2=202409230449
# [93/1000] tm1=202409222334 tm2=202409231934
# [94/1000] tm1=202409231501 tm2=202409241101
# [95/1000] tm1=202409240558 tm2=202409250158
# [96/1000] tm1=202409242107 tm2=202409251707
# [97/1000] tm1=202409251243 tm2=202409260843
# [98/1000] tm1=202409260414 tm2=202409270014
# [99/1000] tm1=202409261948 tm2=202409271548
# [100/1000] tm1=202409271549 tm2=202409281149
# [101/1000] tm1=202409280905 tm2=202409290505
# [102/1000] tm1=202409290102 tm2=202409292102
# [103/1000] tm1=202409291439 tm2=202409301039
# [104/1000] tm1=202409300551 tm2=202410010151
# [105/1000] tm1=202409301300 tm2=202410010900
# [106/1000] tm1=202409302002 tm2=202410011602
# [107/1000] tm1=202410011054 tm2=202410020654
# [108/1000] tm1=202410020211 tm2=202410022211
# [109/1000] tm1=202410021819 tm2=202410031419
# [110/1000] tm1=202410030940 tm2=202410040540
# [111/1000] tm1=202410040117 tm2=202410042117
# [112/1000] tm1=202410041320 tm2=202410050920
# [113/1000] tm1=202410050351 tm2=202410052351
# [114/1000] tm1=202410052137 tm2=202410061737
# [115/1000] tm1=202410061236 tm2=202410070836
# [116/1000] tm1=202410061503 tm2=202410071103
# [117/1000] tm1=202410070520 tm2=202410080120
# [118/1000] tm1=202410072106 tm2=202410081706
# [119/1000] tm1=202410081316 tm2=202410090916
# [120/1000] tm1=202410090557 tm2=202410100157
# [121/1000] tm1=202410092023 tm2=202410101623
# [122/1000] tm1=202410101054 tm2=202410110654
# [123/1000] tm1=202410101856 tm2=202410111456
# [124/1000] tm1=202410111127 tm2=202410120727
# [125/1000] tm1=202410112314 tm2=202410121914
# [126/1000] tm1=202410121435 tm2=202410131035
# [127/1000] tm1=202410130557 tm2=202410140157
# [128/1000] tm1=202410132012 tm2=202410141612
# [129/1000] tm1=202410141136 tm2=202410150736
# [130/1000] tm1=202410141627 tm2=202410151227
# [131/1000] tm1=202410150650 tm2=202410160250
# [132/1000] tm1=202410160109 tm2=202410162109
# [133/1000] tm1=202410161659 tm2=202410171259
# [134/1000] tm1=202410170824 tm2=202410180424
# [135/1000] tm1=202410180219 tm2=202410182219
# [136/1000] tm1=202410181629 tm2=202410191229
# [137/1000] tm1=202410190232 tm2=202410192232
# [138/1000] tm1=202410191837 tm2=202410201437
# [139/1000] tm1=202410201004 tm2=202410210604
# [140/1000] tm1=202410210210 tm2=202410212210
# [141/1000] tm1=202410211900 tm2=202410221500
# [142/1000] tm1=202410221035 tm2=202410230635
# [143/1000] tm1=202410221911 tm2=202410231511
# [144/1000] tm1=202410230326 tm2=202410232326
# [145/1000] tm1=202410231336 tm2=202410240936
# [146/1000] tm1=202410240500 tm2=202410250100
# [147/1000] tm1=202410242105 tm2=202410251705
# [148/1000] tm1=202410251242 tm2=202410260842
# [149/1000] tm1=202410260351 tm2=202410262351
# [150/1000] tm1=202410262150 tm2=202410271750
# [151/1000] tm1=202410271329 tm2=202410280929
# [152/1000] tm1=202410280459 tm2=202410290059
# [153/1000] tm1=202410281326 tm2=202410290926
# [154/1000] tm1=202410290454 tm2=202410300054
# [155/1000] tm1=202410292117 tm2=202410301717
# [156/1000] tm1=202410301448 tm2=202410311048
# [157/1000] tm1=202410310553 tm2=202411010153
# [158/1000] tm1=202410310859 tm2=202411010459
# [159/1000] tm1=202411010038 tm2=202411012038
# [160/1000] tm1=202411011212 tm2=202411020812
# [161/1000] tm1=202411020100 tm2=202411022100
# [162/1000] tm1=202411021642 tm2=202411031242
# [163/1000] tm1=202411030922 tm2=202411040522
# [164/1000] tm1=202411031912 tm2=202411041512
# [165/1000] tm1=202411041301 tm2=202411050901
# [166/1000] tm1=202411050424 tm2=202411060024
# [167/1000] tm1=202411051855 tm2=202411061455
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [168/1000] tm1=202411061456 tm2=202411071056
# [169/1000] tm1=202411070629 tm2=202411080229
# [170/1000] tm1=202411072154 tm2=202411081754
# [171/1000] tm1=202411081601 tm2=202411091201
# [172/1000] tm1=202411090616 tm2=202411100216
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [173/1000] tm1=202411100217 tm2=202411102217
# [174/1000] tm1=202411101742 tm2=202411111342
# [175/1000] tm1=202411110638 tm2=202411120238
# [176/1000] tm1=202411120100 tm2=202411122100
# [177/1000] tm1=202411121624 tm2=202411131224
# [178/1000] tm1=202411130817 tm2=202411140417
# [179/1000] tm1=202411132339 tm2=202411141939
# [180/1000] tm1=202411141524 tm2=202411151124
# [181/1000] tm1=202411150802 tm2=202411160402
# [182/1000] tm1=202411152329 tm2=202411161929
# [183/1000] tm1=202411161454 tm2=202411171054
# [184/1000] tm1=202411162351 tm2=202411171951
# [185/1000] tm1=202411171517 tm2=202411181117
# [186/1000] tm1=202411180637 tm2=202411190237
# [187/1000] tm1=202411182145 tm2=202411191745
# [188/1000] tm1=202411191326 tm2=202411200926
# [189/1000] tm1=202411192249 tm2=202411201849
# [190/1000] tm1=202411201120 tm2=202411210720
# [191/1000] tm1=202411210211 tm2=202411212211
# [192/1000] tm1=202411211750 tm2=202411221350
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [193/1000] tm1=202411221351 tm2=202411230951
# [194/1000] tm1=202411230410 tm2=202411240010
# [195/1000] tm1=202411231859 tm2=202411241459
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [196/1000] tm1=202411241500 tm2=202411251100
# [197/1000] tm1=202411250600 tm2=202411260200
# [198/1000] tm1=202411252113 tm2=202411261713
# [199/1000] tm1=202411261218 tm2=202411270818
# [200/1000] tm1=202411270314 tm2=202411272314
# [201/1000] tm1=202411271844 tm2=202411281444
# [202/1000] tm1=202411280949 tm2=202411290549
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [203/1000] tm1=202411290550 tm2=202411300150
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [204/1000] tm1=202411300151 tm2=202411302151
# [205/1000] tm1=202411301639 tm2=202412011239
# [206/1000] tm1=202412011240 tm2=202412020840
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [207/1000] tm1=202412020841 tm2=202412030441
# [208/1000] tm1=202412030442 tm2=202412040042
# [209/1000] tm1=202412040043 tm2=202412042043
# [210/1000] tm1=202412042044 tm2=202412051644
# [211/1000] tm1=202412051645 tm2=202412061245
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [212/1000] tm1=202412061246 tm2=202412070846
# [213/1000] tm1=202412070847 tm2=202412080447
# [214/1000] tm1=202412080448 tm2=202412090048
# [215/1000] tm1=202412090049 tm2=202412092049
# [216/1000] tm1=202412092050 tm2=202412101650
# [217/1000] tm1=202412101651 tm2=202412111251
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [218/1000] tm1=202412111252 tm2=202412120852
# [219/1000] tm1=202412120853 tm2=202412130453
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [220/1000] tm1=202412130454 tm2=202412140054
# [221/1000] tm1=202412140055 tm2=202412142055
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [222/1000] tm1=202412142056 tm2=202412151656
# [223/1000] tm1=202412151657 tm2=202412161257
# [224/1000] tm1=202412161258 tm2=202412170858
# [225/1000] tm1=202412170859 tm2=202412180459
# [226/1000] tm1=202412180500 tm2=202412190100
# [227/1000] tm1=202412190101 tm2=202412192101
# [228/1000] tm1=202412192102 tm2=202412201702
# [229/1000] tm1=202412201703 tm2=202412211303
# [230/1000] tm1=202412211304 tm2=202412220904
# [231/1000] tm1=202412220905 tm2=202412230505
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [232/1000] tm1=202412230506 tm2=202412240106
# [233/1000] tm1=202412240107 tm2=202412242107
# [234/1000] tm1=202412242108 tm2=202412251708
# [235/1000] tm1=202412251709 tm2=202412261309
# [236/1000] tm1=202412261310 tm2=202412270910
# [237/1000] tm1=202412270911 tm2=202412280511
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [238/1000] tm1=202412280512 tm2=202412290112
# [239/1000] tm1=202412290003 tm2=202412292003
# [240/1000] tm1=202412292000 tm2=202412301600
# [241/1000] tm1=202412301601 tm2=202412311201
# [242/1000] tm1=202412311202 tm2=202501010802
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [243/1000] tm1=202501010803 tm2=202501020403
# [244/1000] tm1=202501020404 tm2=202501030004
# [245/1000] tm1=202501030005 tm2=202501032005
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [246/1000] tm1=202501032006 tm2=202501041606
# [247/1000] tm1=202501041607 tm2=202501051207
# [248/1000] tm1=202501051208 tm2=202501060808
# [249/1000] tm1=202501060809 tm2=202501070409
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [250/1000] tm1=202501070410 tm2=202501080010
# [251/1000] tm1=202501080011 tm2=202501082011
# [252/1000] tm1=202501082003 tm2=202501091603
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [253/1000] tm1=202501091604 tm2=202501101204
# [254/1000] tm1=202501101205 tm2=202501110805
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [255/1000] tm1=202501110806 tm2=202501120406
# [256/1000] tm1=202501120407 tm2=202501130007
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [257/1000] tm1=202501130008 tm2=202501132008
# [258/1000] tm1=202501132009 tm2=202501141609
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [259/1000] tm1=202501141610 tm2=202501151210
# [260/1000] tm1=202501151211 tm2=202501160811
# [261/1000] tm1=202501160812 tm2=202501170412
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [262/1000] tm1=202501170413 tm2=202501180013
# [263/1000] tm1=202501172353 tm2=202501181953
# [264/1000] tm1=202501181954 tm2=202501191554
# [265/1000] tm1=202501191345 tm2=202501200945
# [266/1000] tm1=202501200941 tm2=202501210541
# [267/1000] tm1=202501210411 tm2=202501220011
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [268/1000] tm1=202501220012 tm2=202501222012
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [269/1000] tm1=202501222013 tm2=202501231613
# [270/1000] tm1=202501231614 tm2=202501241214
# [271/1000] tm1=202501241215 tm2=202501250815
# [272/1000] tm1=202501250816 tm2=202501260416
#   [error] ChunkedEncodingError(ProtocolError('Response ended prematurely'))
# [273/1000] tm1=202501260417 tm2=202501270017
#   [error] ChunkedEncodingError(ProtocolError('Response ended prematurely'))
# [274/1000] tm1=202501270018 tm2=202501272018
# [275/1000] tm1=202501272019 tm2=202501281619
# [276/1000] tm1=202501281620 tm2=202501291220
# [277/1000] tm1=202501291221 tm2=202501300821
# [278/1000] tm1=202501300557 tm2=202501310157
# [279/1000] tm1=202501310158 tm2=202501312158
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [280/1000] tm1=202501312159 tm2=202502011759
# [281/1000] tm1=202502011800 tm2=202502021400
# [282/1000] tm1=202502012204 tm2=202502021804
#   [error] ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='apihub.kma.go.kr', port=443): Read timed out. (read timeout=60)"))
# [283/1000] tm1=202502021805 tm2=202502031405
#   [error] ChunkedEncodingError(ProtocolError('Response ended prematurely'))
# [284/1000] tm1=202502031406 tm2=202502041006
#   [error] HTTPError('502 Server Error: Proxy Error for url: https://apihub.kma.go.kr/api/typ01/cgi-bin/url/nph-aws2_min?tm1=202502031406&tm2=202502041006&stn=368&disp=1&help=0&authKey=bWb9TUUATEGm_U1FAExBlg')
# [285/1000] tm1=202502041007 tm2=202502050607
# [286/1000] tm1=202502050608 tm2=202502060208
# [287/1000] tm1=202502060209 tm2=202502062209
# [288/1000] tm1=202502062210 tm2=202502071810
# [289/1000] tm1=202502071448 tm2=202502081048
# [290/1000] tm1=202502081021 tm2=202502090621
# [291/1000] tm1=202502090622 tm2=202502100222
# [292/1000] tm1=202502100117 tm2=202502102117
# [293/1000] tm1=202502101803 tm2=202502111403
# [294/1000] tm1=202502111207 tm2=202502120807
# [295/1000] tm1=202502120048 tm2=202502122048
# [296/1000] tm1=202502121956 tm2=202502131556
# [297/1000] tm1=202502131113 tm2=202502140713
# [298/1000] tm1=202502140519 tm2=202502150119
# [299/1000] tm1=202502150120 tm2=202502152120
# [300/1000] tm1=202502152121 tm2=202502161721
# [301/1000] tm1=202502161722 tm2=202502171322
# [302/1000] tm1=202502171323 tm2=202502180923
# [303/1000] tm1=202502180924 tm2=202502190524
# [304/1000] tm1=202502190525 tm2=202502200125
# [305/1000] tm1=202502200008 tm2=202502202008
# [306/1000] tm1=202502202000 tm2=202502211600
# [307/1000] tm1=202502210659 tm2=202502220259
# [308/1000] tm1=202502212207 tm2=202502221807
# [309/1000] tm1=202502221708 tm2=202502231308
# [310/1000] tm1=202502231309 tm2=202502240909
# [311/1000] tm1=202502240516 tm2=202502250116
# [312/1000] tm1=202502250117 tm2=202502252117
# [313/1000] tm1=202502252118 tm2=202502261718
# [314/1000] tm1=202502261603 tm2=202502271203
# [315/1000] tm1=202502271204 tm2=202502280804
# [316/1000] tm1=202502272347 tm2=202502281947
# [317/1000] tm1=202502281948 tm2=202503011548
# [318/1000] tm1=202503011535 tm2=202503021135
# [319/1000] tm1=202503021136 tm2=202503030736
# [320/1000] tm1=202503030737 tm2=202503040337
# [321/1000] tm1=202503040338 tm2=202503042338
# [322/1000] tm1=202503042339 tm2=202503051939
# [323/1000] tm1=202503051706 tm2=202503061306
# [324/1000] tm1=202503061248 tm2=202503070848
# [325/1000] tm1=202503070733 tm2=202503080333
# [326/1000] tm1=202503080308 tm2=202503082308
# [327/1000] tm1=202503081459 tm2=202503091059
# [328/1000] tm1=202503090303 tm2=202503092303
# [329/1000] tm1=202503092304 tm2=202503101904
# [330/1000] tm1=202503101905 tm2=202503111505
# [331/1000] tm1=202503111432 tm2=202503121032
# [332/1000] tm1=202503121033 tm2=202503130633
# [333/1000] tm1=202503130634 tm2=202503140234
# [334/1000] tm1=202503140104 tm2=202503142104
# [335/1000] tm1=202503142013 tm2=202503151613
# [336/1000] tm1=202503151614 tm2=202503161214
# [337/1000] tm1=202503161215 tm2=202503170815
# [338/1000] tm1=202503170816 tm2=202503180416
# [339/1000] tm1=202503180417 tm2=202503190017
# [340/1000] tm1=202503181902 tm2=202503191502
# [341/1000] tm1=202503191445 tm2=202503201045
# [342/1000] tm1=202503201046 tm2=202503210646
# [343/1000] tm1=202503210647 tm2=202503220247
# [344/1000] tm1=202503212347 tm2=202503221947
# [345/1000] tm1=202503221006 tm2=202503230606
# [346/1000] tm1=202503230541 tm2=202503240141
# [347/1000] tm1=202503232342 tm2=202503241942
# [348/1000] tm1=202503241846 tm2=202503251446
# [349/1000] tm1=202503251336 tm2=202503260936
# [350/1000] tm1=202503251532 tm2=202503261132
# [351/1000] tm1=202503261130 tm2=202503270730
# [352/1000] tm1=202503270731 tm2=202503280331
# [353/1000] tm1=202503280332 tm2=202503282332
# [354/1000] tm1=202503282333 tm2=202503291933
# [355/1000] tm1=202503291934 tm2=202503301534
# [356/1000] tm1=202503301535 tm2=202503311135
# [357/1000] tm1=202503311136 tm2=202504010736
# [358/1000] tm1=202504010737 tm2=202504020337
# [359/1000] tm1=202504020338 tm2=202504022338
# [360/1000] tm1=202504022039 tm2=202504031639
# [361/1000] tm1=202504031415 tm2=202504041015
# [362/1000] tm1=202504040939 tm2=202504050539
# [363/1000] tm1=202504050242 tm2=202504052242
# [364/1000] tm1=202504052058 tm2=202504061658
# [365/1000] tm1=202504061352 tm2=202504070952
# [366/1000] tm1=202504070750 tm2=202504080350
# [367/1000] tm1=202504080237 tm2=202504082237
# [368/1000] tm1=202504080901 tm2=202504090501
# [369/1000] tm1=202504090502 tm2=202504100102
# [370/1000] tm1=202504100103 tm2=202504102103
# [371/1000] tm1=202504102104 tm2=202504111704
# [372/1000] tm1=202504111705 tm2=202504121305
# [373/1000] tm1=202504121306 tm2=202504130906
# [374/1000] tm1=202504130907 tm2=202504140507
# [375/1000] tm1=202504132306 tm2=202504141906
# [376/1000] tm1=202504141907 tm2=202504151507
# [377/1000] tm1=202504150620 tm2=202504160220
# [378/1000] tm1=202504160021 tm2=202504162021
# [379/1000] tm1=202504161815 tm2=202504171415
# [380/1000] tm1=202504171233 tm2=202504180833
# [381/1000] tm1=202504180541 tm2=202504190141
# [382/1000] tm1=202504182308 tm2=202504191908
# [383/1000] tm1=202504191633 tm2=202504201233
# [384/1000] tm1=202504201153 tm2=202504210753
# [385/1000] tm1=202504210754 tm2=202504220354
# [386/1000] tm1=202504220251 tm2=202504222251
# [387/1000] tm1=202504222204 tm2=202504231804
# [388/1000] tm1=202504231805 tm2=202504241405
# [389/1000] tm1=202504241406 tm2=202504251006
# [390/1000] tm1=202504251007 tm2=202504260607
# [391/1000] tm1=202504260608 tm2=202504270208
# [392/1000] tm1=202504270209 tm2=202504272209
# [393/1000] tm1=202504272124 tm2=202504281724
# [394/1000] tm1=202504281725 tm2=202504291325
# [395/1000] tm1=202504291326 tm2=202504300926
# [396/1000] tm1=202504300640 tm2=202505010240
# [397/1000] tm1=202505010032 tm2=202505012032
# [398/1000] tm1=202505011958 tm2=202505021558
# [399/1000] tm1=202505021559 tm2=202505031159
# [400/1000] tm1=202505031200 tm2=202505040800
# [401/1000] tm1=202505040801 tm2=202505050401
# [402/1000] tm1=202505050402 tm2=202505060002
# [403/1000] tm1=202505060003 tm2=202505062003
# [404/1000] tm1=202505062004 tm2=202505071604
# [405/1000] tm1=202505070742 tm2=202505080342
# [406/1000] tm1=202505071837 tm2=202505081437
# [407/1000] tm1=202505081438 tm2=202505091038
# [408/1000] tm1=202505090910 tm2=202505100510
# [409/1000] tm1=202505100309 tm2=202505102309
# [410/1000] tm1=202505102037 tm2=202505111637
# [411/1000] tm1=202505111236 tm2=202505120836
# [412/1000] tm1=202505120544 tm2=202505130144
# [413/1000] tm1=202505121839 tm2=202505131439
# [414/1000] tm1=202505131151 tm2=202505140751
# [415/1000] tm1=202505140427 tm2=202505150027
# [416/1000] tm1=202505142322 tm2=202505151922
# [417/1000] tm1=202505151833 tm2=202505161433
# [418/1000] tm1=202505161323 tm2=202505170923
# [419/1000] tm1=202505170924 tm2=202505180524
# [420/1000] tm1=202505180525 tm2=202505190125
# [421/1000] tm1=202505190126 tm2=202505192126
# [422/1000] tm1=202505192127 tm2=202505201727
# [423/1000] tm1=202505201728 tm2=202505211328
# [424/1000] tm1=202505202249 tm2=202505211849
# [425/1000] tm1=202505211808 tm2=202505221408
# [426/1000] tm1=202505221305 tm2=202505230905
# [427/1000] tm1=202505230749 tm2=202505240349
# [428/1000] tm1=202505232342 tm2=202505241942
# [429/1000] tm1=202505241918 tm2=202505251518
# [430/1000] tm1=202505251120 tm2=202505260720
# [431/1000] tm1=202505260335 tm2=202505262335
# [432/1000] tm1=202505262336 tm2=202505271936
# [433/1000] tm1=202505271011 tm2=202505280611
# [434/1000] tm1=202505280610 tm2=202505290210
# [435/1000] tm1=202505290116 tm2=202505292116
# [436/1000] tm1=202505291720 tm2=202505301320
# [437/1000] tm1=202505301321 tm2=202505310921
# [438/1000] tm1=202505310922 tm2=202506010522
# [439/1000] tm1=202506010523 tm2=202506020123
# [440/1000] tm1=202506020124 tm2=202506022124
# [441/1000] tm1=202506022125 tm2=202506031725
# [442/1000] tm1=202506031726 tm2=202506041326
# [443/1000] tm1=202506041327 tm2=202506050927
# [444/1000] tm1=202506050928 tm2=202506060528
# [445/1000] tm1=202506051659 tm2=202506061259
# [446/1000] tm1=202506061100 tm2=202506070700
# [447/1000] tm1=202506062055 tm2=202506071655
# [448/1000] tm1=202506071008 tm2=202506080608
# [449/1000] tm1=202506080318 tm2=202506082318
# [450/1000] tm1=202506082153 tm2=202506091753
# [451/1000] tm1=202506091626 tm2=202506101226
# [452/1000] tm1=202506100444 tm2=202506110044
# [453/1000] tm1=202506110045 tm2=202506112045
# [454/1000] tm1=202506112046 tm2=202506121646
# [455/1000] tm1=202506120142 tm2=202506122142
# [456/1000] tm1=202506122143 tm2=202506131743
# [457/1000] tm1=202506131639 tm2=202506141239
# [458/1000] tm1=202506140758 tm2=202506150358
# [459/1000] tm1=202506150309 tm2=202506152309
# [460/1000] tm1=202506152124 tm2=202506161724
# [461/1000] tm1=202506161459 tm2=202506171059
# [462/1000] tm1=202506170902 tm2=202506180502
